# %%
from langchain_community.document_loaders import TextLoader

loader = TextLoader("data.txt")
loader

text_doc = loader.load()
text_doc
# Out:
# [Document(metadata={'source': 'data.txt'}, page_content='hello')]

# %%
from langchain_community.document_loaders import PyPDFLoader

loader = PyPDFLoader("dummy-pdf_2.pdf")
loader

pdf_doc = loader.load()
pdf_doc[0]
# Out:
# Document(metadata={'producer': 'Acrobat Distiller 8.1.0 (Windows)', 'creator': 'Acrobat PDFMaker 8.1 for Word', 'creationdate': '2009-08-25T14:35:18+01:00', 'author': 'NewUser', 'moddate': '2009-08-25T14:35:21+01:00', 'company': 'SDL International', 'sourcemodified': 'D:20090825133443', 'title': 'Dummy PDF download', 'source': 'dummy-pdf_2.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='Dummy PDF download')
